# %%
import osmnx as ox
ox.config(log_console=False)

# import logging
# logger = logging.getLogger()
# logger.setLevel(logging.CRITICAL)
import logging, sys
logging.disable(sys.maxsize)

# %%
# !pip install fastapi pydantic

from find_route_functions import *

limuru_drives = ox.graph_from_address('Limuru',network_type='drive')

# %%
limuru_buildings = ox.geometries_from_place('Limuru',tags={'building': True})
type(limuru_buildings)
# G_projected = ox.project_graph(limuru_drives)

# ax = limuru_buildings.plot()

ox.plot_graph(limuru_drives)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
ox.plot_graph(limuru_drives)
# Out:
# 2021-11-16 08:52:05 Begin plotting the graph...
# 2021-11-16 08:52:05 Created edges GeoDataFrame from graph
# 2021-11-16 08:52:05 Created nodes GeoDataFrame from graph
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)
# 2021-11-16 08:52:05 Finished plotting the graph

# %%
nodes,edges = ox.graph_to_gdfs(limuru_drives,nodes=True,edges=True)
nodes.head()
# Out:
#                   y          x  street_count                   geometry
# osmid
# 499462423 -1.109169  36.631060             3  POINT (36.63106 -1.10917)
# 677331525 -1.108682  36.632448             3  POINT (36.63245 -1.10868)
# 677331573 -1.107045  36.638385             3  POINT (36.63839 -1.10705)
# 677331574 -1.107943  36.639308             3  POINT (36.63931 -1.10794)
# 677331589 -1.108708  36.642381             3  POINT (36.64238 -1.10871)

# %%
ox.nearest_nodes(limuru_drives,X=36.632448,Y=-1.108682)
# Out:
# 2021-11-16 08:55:33 Created nodes GeoDataFrame from graph
# 677331525

# %%
ox.nearest_nodes(limuru_drives,X=36.631060,Y=-1.109169)
# Out:
# 2021-11-16 10:14:35 Created nodes GeoDataFrame from graph
# 499462423

# %%
type(limuru_drives.nodes)
# Out:
# networkx.classes.reportviews.NodeView

# %%
map = ox.plot_graph_folium(limuru_drives, figsize=(10,10))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
nodes,edges = ox.graph_to_gdfs(limuru_drives)
nodes.plot()
# Out:
# <AxesSubplot:>

# %%
edges.plot()
# Out:
# <AxesSubplot:>

# %%
ptAX = 36.645
ptAY = -1.1225
ptBX = 36.630
ptBY = -1.1075
